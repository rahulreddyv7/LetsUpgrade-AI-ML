# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_excel("C:/Users/RAHUL REDDY/Desktop/AIML/Letsupgrade/AI-ML-July-2020-master/Day-23/dataset/Linear Regression.xlsx",sheet_name='Linear Regression')
data.head()
# Out:
#     price  sqft_living  bedrooms  bathrooms  floors
# 0  221900         1180         3       1.00     1.0
# 1  538000         2570         3       2.25     2.0
# 2  180000          770         2       1.00     1.0
# 3  604000         1960         4       3.00     1.0
# 4  510000         1680         3       2.00     1.0

# %%
data.plot(x = 'sqft_living', y = 'price' , style = '*')

# %%
data.plot(x = 'bedrooms', y = 'price' , style = '*')

# %%
data.plot(x = 'bathrooms', y = 'price' , style = '*')

# %%
data.plot(x = 'floors', y = 'price' , style = '*')

# %% [markdown]
# # sqft_living vs Price

# %%
X_train = data['sqft_living'].values.reshape(-1,1)
y_train = data['price']
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('coefficient of determination : ' ,reg.score(X_train,y_train))
print('intercept : ',reg.intercept_)
print('Slope : ' ,reg.coef_)
# Out:
# coefficient of determination :  0.492853214845565
# intercept :  -43580.740327085485
# Slope :  [280.62356663]

# %%
X_test = np.array([2580]).reshape(-1,1)
y_pred = reg.predict(X_test)
print("Predicted respondce for given X_test sqft is : ",y_pred)
# Out:
# Predicted respondce for given X_test sqft is :  [680428.06158772]

# %% [markdown]
# # bedrooms vs Price

# %%
X_train = data['bedrooms'].values.reshape(-1,1)
y_train = data['price']
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('coefficient of determination : ' ,reg.score(X_train,y_train))
print('intercept : ',reg.intercept_)
print('Slope : ' ,reg.coef_)
# Out:
# coefficient of determination :  0.09507947451573184
# intercept :  129802.35737890482
# Slope :  [121716.12623836]

# %%
X_test = np.array([3]).reshape(-1,1)
y_pred = reg.predict(X_test)
print("Predicted respondce for given X_test sqft is : ",y_pred)
# Out:
# Predicted respondce for given X_test sqft is :  [494950.736094]

# %% [markdown]
# # bathrooms vs Price

# %%
X_train = data['bathrooms'].values.reshape(-1,1)
y_train = data['price']
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('coefficient of determination : ' ,reg.score(X_train,y_train))
print('intercept : ',reg.intercept_)
print('Slope : ' ,reg.coef_)
# Out:
# coefficient of determination :  0.27576939871609185
# intercept :  10708.310251930263
# Slope :  [250326.51555367]

# %%
X_test = np.array([4]).reshape(-1,1)
y_pred = reg.predict(X_test)
print("Predicted respondce for given X_test sqft is : ",y_pred)
# Out:
# Predicted respondce for given X_test sqft is :  [1012014.37246662]

# %% [markdown]
# # floors vs Price

# %%
X_train = data['floors'].values.reshape(-1,1)
y_train = data['price']
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('coefficient of determination : ' ,reg.score(X_train,y_train))
print('intercept : ',reg.intercept_)
print('Slope : ' ,reg.coef_)
# Out:
# coefficient of determination :  0.06594309889233674
# intercept :  279198.5152416884
# Slope :  [174588.80996645]

# %%
X_test = np.array([1]).reshape(-1,1)
y_pred = reg.predict(X_test)
print("Predicted respondce for given X_test sqft is : ",y_pred)
# Out:
# Predicted respondce for given X_test sqft is :  [453787.32520814]

# %% [markdown]
# # Multiple regression:

# %%
X = data[['sqft_living','bedrooms','bathrooms','floors']]
y = data.price
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('coefficient of determination : ' ,model.score(X,y))
print('intercept : ',reg.intercept_)
print('Slope : ' ,reg.coef_)
# Out:
# coefficient of determination :  0.5069198583441098
# intercept :  279198.5152416884
# Slope :  [174588.80996645]

# %%
y_pred = model.predict([[2890,3,4,2]])
print("The predicted value of the given features is : ",y_pred)
# Out:
# The predicted value of the given features is :  [827087.29572225]
